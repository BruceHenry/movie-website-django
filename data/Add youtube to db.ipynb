# %%
import pandas as pd
import numpy as np

youtube = pd.read_csv('youtube_movie.csv')
print(len(youtube))
# Out:
# 1063

# %%
for key, row in youtube.iterrows():
    print('UPDATE movie_movie SET movielenid = {}, youtubeId ="{}" WHERE movieId = "{}";'.format(row['movielenID'], row['youtubeId'], row['movieID']))
# Out:
# UPDATE movie_movie SET movielenid = 55069, youtubeId ="xzitmvuOLKE" WHERE movieId = "tt1032846";
# UPDATE movie_movie SET movielenid = 57274, youtubeId ="YQUkX_XowqI" WHERE movieId = "tt1038988";
# UPDATE movie_movie SET movielenid = 57368, youtubeId ="IvNkGm8mxiM" WHERE movieId = "tt1060277";
# UPDATE movie_movie SET movielenid = 57532, youtubeId ="RY-zJtYYolo" WHERE movieId = "tt1073498";
# UPDATE movie_movie SET movielenid = 58107, youtubeId ="bL2wDI-O5YQ" WHERE movieId = "tt1023481";
# UPDATE movie_movie SET movielenid = 58146, youtubeId ="Z3MFmPjFm-o" WHERE movieId = "tt1001562";
# UPDATE movie_movie SET movielenid = 58627, youtubeId ="2tc-RPjZRm8" WHERE movieId = "tt1023111";
# UPDATE movie_movie SET movielenid = 59336, youtubeId ="uRRTjflCJew" WHERE movieId = "tt1012804";
# UPDATE movie_movie SET movielenid = 59421, youtubeId ="EsO3PfQiXy8" WHERE movieId = "tt1033643";
# UPDATE movie_movie SET movielenid = 60293, youtubeId ="LBewdRfdH4U" WHERE movieId = "tt1082886";
# ...
